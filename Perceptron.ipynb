# %% [markdown]
# ## What is Perceptron ??
#
# A Perceptron is a type of artificial neuron, or neural-network unit, that performs computational to identify pattern or features in input data. It is a machine learning algorithm that's used for supervised learning of binary classifiers.
#
# ![image.png](attachment:ef3465a2-3763-47b9-b3d3-fafa74293752.png)

# %% [markdown]
# ## Basic Componets of Perceptron
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/general-diagram-of-perceptron-for-supervised-learning_4.jpg)
#
# ## 1. Input Layer
#
# **The input layer consists of one or more input neurons, which receives input signals from the external world or from other layers of the neural network.**
#
# ## 2. Weights
#
# **Each input neuron is associated with a weight, which represents the strength of the connection between the input neuron and the output neuron.**
#
# ## 3. Bias
# **A bias term is added to the input layer to provide the perceptron with additional flexibility in modeling complex patterns in the input data.**
#
# ## 4. Activation Function
#
#  **The activation function determines the output of the perceptron based on the weighted sum of the inputs and the bias term. Common activation functions used in perceptrons include the step function, sigmoid function, and ReLU function.**
#
#  ## 5. Output
#  **The output of the perceptron is a single binary value, either 0 or 1, which indicates the class or category to which the input data belongs**
#
#  ## 6. Training Algorithm
#
#  **The perceptron is typically trained using a supervised learning algorithm such as the perceptron learning algorithm or backpropagation. During training, the weights and biases of the perceptron are adjusted to minimize the error between the predicted output and the true output for a given set of training examples.**
#
# **Overall, the perceptron is a simple yet powerful algorithm that can be used to perform binary classification tasks and has paved the way for more complex neural networks used in deep learning today.**

# %% [markdown]
# ## Type Of Perceptron
# ## 1. Single Layer
# **Single layer perceptron can learn only linearly separable patterns.**
# ## 2. Multilayer
# **Multilayer perceptrons can learn about two or more layers having a greater processing power.**
#
# **The Perceptron algorithm learns the weights for the input signals in order to draw a linear decision boundary.**
#
# ![](https://rezaborhani.github.io/mlr/mlrefined_images/superlearn_images/Fig_4_1.png)

# %% [markdown]
# ### What is Supervised Learning ??
# **Supervised Learning is a type of Machine Learning used to learn models from labeled training data. It enables output prediction for future or unseen data.**

# %% [markdown]
# ## History Of Perceptron
#
# **Perceptron is the nurturing step of an Artificial Neural Link. In 19h century, Mr. Frank Rosenblatt invented the Perceptron to perform specific high-level calculations to detect input data capabilities or business intelligence.**

# %% [markdown]
# # 1. Single-Layer Perceptron

# %% [markdown]
# ## How does perceptron work ??

# %% [markdown]
# <img src='https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron_work.png' width=800></img>
#
# **Perceptron is considered a single-layer neural link with four main parameters. The perceptron model begins with multiplying all input values and their weights, then adds these values to create the weighted sum. Further, this weighted sum is applied to the activation function ‘f’ to obtain the desired output. This activation function is also known as the step function and is represented by ‘f.’**

# %% [markdown]
# **This step function or Activation function is vital in ensuring that output is mapped between (0,1) or (-1,1).**

# %% [markdown]
# ## Step 1:
# **Multiply all input values with corresponding weight values and then add to calculate the weighted sum. The following is the mathematical expression of it:**
#
# **``∑wi*xi = x1*w1 + x2*w2 + x3*w3+……..x4*w4``**
#
# **Add a term called bias ‘b’ to this weighted sum to improve the model’s performance.**

# %% [markdown]
# ## Step 2:
# **An activation function is applied with the above-mentioned weighted sum giving us an output either in binary form or a continuous value as follows:**
#
# **``Y=f(∑wi*xi + b)``**
#
# **Activation function simply used in 'step' or 'sigmoid' function.**
#
# - In step function if ∑wi*xi > 0 then output is 1 else 0
# - In sigmoid function :
#   - first calculate sigmoid values using this formula
#     - ![](https://wikimedia.org/api/rest_v1/media/math/render/svg/faaa0c014ae28ac67db5c49b3f3e8b08415a3f2b)
#   - if sigmoid value is greater than 0.5 then 1 else 0

# %% [markdown]
# ## Perceptron : Decision Function
# **A decision function φ(z) of Perceptron is defined to take a linear combination of x and w vectors.**
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_12.jpg)
#
# **Where w and x respectively weights and input vectors**
#
# **The value z is the decision function is given by:**
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_13.jpg)
#
# **The decision function is +1 if z is greater than a threshold θ, and it is -1 otherwise.**
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_14.jpg)
#
# ### This is the Perceptron algorithm.

# %% [markdown]
# ## Bias Unit
# **For simplicity, the threshold θ can be brought to the left and represented as w0x0, where w0= -θ and x0= 1.**
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_15.jpg)
#
# **The value w0  is called the bias unit.**
#
# **The decision function then becomes:**
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_16.jpg)

# %% [markdown]
# ## Output
# **The figure shows how the decision function squashes wTx to either +1 or -1 and how it can be used to discriminate between two linearly separable classes.**
#
# ![](https://www.simplilearn.com/ice9/free_resources_article_thumb/Perceptron/Perceptron_17.jpg)

# %% [markdown]
# ## Perceptron Learning -- How to train a perceptron ??

# %% [markdown]
# ## step 1 :
# - Initialize weight and bias (w & b)
# - Randomly select an data points
# - Calculate y_hat for particular data point
# - Then calculate loss (L) in my case **loss function** as ``binary_cross_entropy`` for **classification problem**
# - Accordoing to loss, update weight and bias using gradient descent algorithm
#
#   ``new_weight = old_weight - learning_rate * gradient_of_weight``
#
#   ``new_bias = old_bias - learning_rate * gradient_of_bias``

# %% [markdown]
# ## Perceptron Algorithm Implementation In Python

# %%
class Perceptron:
    def __init__(self):
        self.coef_= None
        self.intercept_ = None

    def fit(self,X,y):
       ## add 1 into input
       X = np.insert(X,0,1,axis=1)
       ## intialize weights and bias -- 1
       weights = np.ones(X.shape[1])
       ## set learning rate 
       lr = 0.1
       ## run epochs 
       for i in range(1000):
           # randomly select a data point
           j = np.random.randint(0,X.shape[0])
           ## calculate y_hat 
           y_hat = np.dot(X[j],weights)
           ## apply step function -- activation function
           if y_hat > 0:
               y_hat = 1
           else:
               y_hat = 0
           ## update weights and bias 
           weights = weights +  lr * (y[j]-y_hat) * X[j]
           
       self.intercept_ = weights[0]
       self.coef_ = weights[1:]
       return self.coef_,self.intercept_

    def predict(self,X):
       return X * self.coef_ + self.intercept_

# %% [markdown]
# ## Test Algorithm

# %% [markdown]
# ### 1. Genrate an dataset for test algorithm

# %%
from sklearn.datasets import make_classification
import pandas as pd 
import numpy as np 

## generate data
X,y = make_classification(n_samples=100,n_features=2,n_classes=2,n_clusters_per_class=1,class_sep=2,n_redundant=0,n_informative=1)

pd.DataFrame({
    'X1':X[:,0],
    'X2':X[:,1],
    'y':y
})
# Out:
#           X1        X2  y
# 0  -2.106362  0.068844  0
# 1   1.963878 -0.612770  1
# 2   1.357535 -1.675561  1
# 3  -1.911365 -0.867609  0
# 4  -2.090640  1.351313  0
# ..       ...       ... ..
# 95  2.336639  0.816396  1
# 96 -1.709082  1.222131  0
# 97  3.035898 -0.429570  1
# 98 -2.329571 -0.223784  0
# 99  2.970216  0.417816  1
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 2. Plot the data

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ## 3. Test Algorithm

# %%
pt = Perceptron()

# %%
pt.fit(X,y)
# Out:
# (array([0.47352658, 0.17521043]), 0.30000000000000016)

# %%
y_pred = pt.predict(X)

# %% [markdown]
# ## 4. Plot Decision Boundary

# %%
## calculate m and b 
m = -(pt.coef_[0]/pt.coef_[1])
b = -(pt.intercept_/pt.coef_[1])

## generate data points for predictions
x_input = np.linspace(-3,3,100)
## predicts the output for generated data points
y_input = m * x_input + b

## plot output line

plt.scatter(X[:,0],X[:,1],c=y,s=50,linewidths=3)
plt.plot(x_input,y_input,c='red')
plt.title('Plot Decision Boundary of Perceptron Model')
plt.grid()
plt.show()

# %% [markdown]
# ## Scikit-Learn Implemenation Perceptron

# %%
from sklearn.linear_model import Perceptron

pt = Perceptron()
# train model
pt.fit(X,y)
# Out:
# Perceptron()

# %% [markdown]
# ## Plot Decison Boundary

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X[:,0:2],y,clf=pt)
plt.title('Plot Decison Boundary Scikit Learn Implementation')
plt.show()

# %% [markdown]
# ## Advantages of Perceptron
# - It works well both small and large input data.
# - Helps us to obtain quick predictions after training data.
# - Helps us to obtain the same accuracy ratio with big and small data.
#
# ## Disdvantages
# - The model functioning depends on the quality of training.
# - It is tough to predict how much the dependent variable affects each independent variable.

# %% [markdown]
# ## Limitation Of Perceptron Model

# %% [markdown]
# **The following are the limitation of a Perceptron model:**
# - The output of a perceptron can only be a binary number (0 or 1) due to the hard-edge transfer function.
# - It can only be used to classify the linearly separable sets of input vectors. If the input vectors are non-linear, it is not easy to classify them correctly.

# %% [markdown]
# ## Problems With Perceptron (single_layer perceptron)
# ## It does not captures non-linear data as well

# %% [markdown]
# ## Example

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

## genrate non-linear data
X,y = make_circles(n_samples=100,shuffle=True,noise=0.2,)

# %%
## Plot Non-Linear data
plt.scatter(X[:,0],X[:,1],c=y)
plt.title('Non-Linear Data')
plt.show()

# %% [markdown]
# ## Train Perceptron Model

# %%
from sklearn.linear_model import Perceptron
from mlxtend.plotting import plot_decision_regions

pt = Perceptron()
## train model
pt.fit(X,y)

## plot decision boundary
plot_decision_regions(X[:,0:2],y,clf=pt)
plt.title('Perceptron Model Decision Boundary for Non-Linear Data')
plt.show()

# %% [markdown]
# ## You Noticed that Perceptron Model Does not Correctly Classify Non-Linear data.

# %% [markdown]
# ## Solution -- In Next Class ......

# %% [markdown]
# ![](https://img.freepik.com/free-photo/3d-rendering-kid-playing-digital-game_23-2150898496.jpg)
#
# ## Keep Learning , Never Give Up !!!!
